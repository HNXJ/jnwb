# %% [markdown]
# # Suite 03: TFR LFP 2D Heatmap
#
# Generates 2D heatmaps of Time-Frequency Representations (TFR) across all brain areas locked to the onset of omission from -1250ms pre-omission to +1750ms post-omission.

# %%
import jnwb as jn
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load Omission Session
session = jn.read('D:/workspace/data/nwb/sub-V182o_ses-260629.nwb')
